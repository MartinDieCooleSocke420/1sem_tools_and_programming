# %%
import pandas as pd
import numpy as np

# %%
results = pd.read_csv("data/results.csv")

# %%
results
# Out:
#         athlete  year  season                sport  \
# 0          1014  2020  Summer         Table Tennis
# 1          2069  2020  Summer              Archery
# 2          2069  2020  Summer              Archery
# 3         11260  2020  Summer  Equestrian Jumping
# 4         11260  2020  Summer  Equestrian Jumping
# ...         ...   ...     ...                  ...
# 291705    80232  1896  Summer             Shooting
# 291706    80232  1896  Summer             Shooting
# 291707    80233  1896  Summer             Shooting
# 291708    80234  1896  Summer             Shooting
# 291709   102578  1896  Summer             Shooting
#
#                                           discipline   pos medal  \
# 0                                     Singles, Women  65.0   NaN
# 1                                        Team, Mixed  24.0   NaN
# 2                                    Individual, Men  33.0   NaN
# 3                                   Individual, Open   5.0   NaN
# 4                                         Team, Open   1.0  Gold
# ...                                              ...   ...   ...
# 291705  Free Rifle, Three Positions, 300 metres, Men   NaN   NaN
# 291706               Military Rifle, 200 metres, Men  11.0   NaN
# 291707               Military Rifle, 200 metres, Men   NaN   NaN
# 291708               Military Rifle, 200 metres, Men   NaN   NaN
# 291709  Free Rifle, Three Positions, 300 metres, Men   NaN   NaN
#
#               country country_code             team
# 0             Nigeria          NGR              NaN
# 1              Poland          POL  Sylwia Zyzańska
# 2              Poland          POL              NaN
# 3              Sweden          SWE              NaN
# 4              Sweden          SWE           Sweden
# ...               ...          ...              ...
# 291705         Greece          GRE              NaN
# 291706         Greece          GRE              NaN
# 291707  Great Britain          GBR              NaN
# 291708         Greece          GRE              NaN
# 291709         Greece          GRE              NaN
#
# [291710 rows x 10 columns]

# %%
athletes = pd.read_csv(filepath_or_buffer="data/athletes.txt", sep=";")

# %%
merged = pd.merge(left = athletes, right = results, how="inner")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291710 entries, 0 to 291709
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete       291710 non-null  float64
#  1   name          291710 non-null  object
#  2   sex           291710 non-null  object
#  3   born          289087 non-null  object
#  4   died          61922 non-null   object
#  5   affiliations  198770 non-null  object
#  6   title         834 non-null     object
#  7   measurements  228351 non-null  object
#  8   year          291710 non-null  int64
#  9   season        291710 non-null  object
#  10  sport         291710 non-null  object
#  11  discipline    291710 non-null  object
#  12  pos           222296 non-null  float64
#  13  medal         41913 non-null   object
#  14  country       291710 non-null  object
#  15  country_code  291710 non-null  object
#  16  team          114693 non-null  object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 37.8+ MB

# %%
merged.head()
# Out:
#    athlete                   name   sex  \
# 0      1.0  Jean-François•Blanchy  Male
# 1      1.0  Jean-François•Blanchy  Male
# 2      1.0  Jean-François•Blanchy  Male
# 3      1.0  Jean-François•Blanchy  Male
# 4      1.0  Jean-François•Blanchy  Male
#
#                                           born  \
# 0  12 December 1886 in Bordeaux, Gironde (FRA)
# 1  12 December 1886 in Bordeaux, Gironde (FRA)
# 2  12 December 1886 in Bordeaux, Gironde (FRA)
# 3  12 December 1886 in Bordeaux, Gironde (FRA)
# 4  12 December 1886 in Bordeaux, Gironde (FRA)
#
#                                                 died affiliations title  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...          NaN   NaN
# 1  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...          NaN   NaN
# 2  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...          NaN   NaN
# 3  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...          NaN   NaN
# 4  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...          NaN   NaN
#
#   measurements  year  season   sport      discipline   pos medal country  \
# 0          NaN  1920  Summer  Tennis    Singles, Men  32.0   NaN  France
# 1          NaN  1920  Summer  Tennis  Doubles, Mixed   8.0   NaN  France
# 2          NaN  1920  Summer  Tennis    Doubles, Men   4.0   NaN  France
# 3          NaN  1912  Summer  Tennis    Singles, Men  17.0   NaN  France
# 4          NaN  1912  Summer  Tennis    Doubles, Men   NaN   NaN  France
#
#   country_code             team
# 0          FRA              NaN
# 1          FRA  Jeanne Vaussard
# 2          FRA  Jacques Brugnon
# 3          FRA              NaN
# 4          FRA   Jean Montariol
